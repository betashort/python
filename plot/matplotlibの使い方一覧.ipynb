# %% [markdown]
# - 折れ線グラフ
# - 散布図
# - 棒グラフ
# -

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
data, labels = load_iris().data, load_iris().target

# %% [markdown]
# # 散布図

# %%
plt.scatter(data[:,0], data[:,1])
plt.show()

# %% [markdown]
# ## アニメーション

# %%
plt.figure(figsize=(16,10))
plt.subplot(2, 2, 1)
plt.scatter(data[:,0], data[:,1])
plt.subplot(2, 2, 2)
plt.scatter(data[:,0], data[:,1])
plt.subplot(2, 2, 3)
plt.scatter(data[:,0], data[:,1])
plt.subplot(2, 2, 4)
plt.scatter(data[:,0], data[:,1])
plt.show()
