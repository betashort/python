# %%
import dicom
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
d1 = dicom.read_file("../dicom_picture/MR_JPG_IR6a.dcm")
d2 = dicom.read_file("../dicom_picture/MR_LEE_IR6a.dcm")

# %%
d2.PatientName
# Out:
# 'SUIDOBASHI^SABURO'

# %%
plt.imshow(d2.pixel_array)

# %%
d2.pixel_array
# Out:
# array([[161, 313, 265, ..., 288, 347, 353],
#        [134, 198, 224, ..., 218, 419, 331],
#        [107, 162, 241, ..., 337, 416, 292],
#        ...,
#        [246, 407, 292, ..., 237, 295, 294],
#        [148, 222, 380, ..., 259, 177, 241],
#        [206, 191, 295, ..., 198, 222, 355]], dtype=int16)

# %%
d2.pixel_array.shape
# Out:
# (320, 320)

# %%
for n,val in enumerate(d2.pixel_array.flat): # example: zero anything < 300
    if val < 300:
        d2.pixel_array.flat[n]=0
