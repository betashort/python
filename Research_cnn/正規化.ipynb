# %%
import numpy as np
#データの読み込みと前処理
from keras.utils import np_utils
from keras.datasets import mnist
#kerasでCNN構築
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import Adam
#時間計測
import time
import cv2
 
'''
データの読み込みと前処理
'''
#データの読み込み
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#訓練用
#X

X_train = X_train.reshape(60000, 28, 28, 1)
X_train = X_train.astype('float32')#型を変更
X_train /= X_train.max() #0から1.0の範囲に変換

#y
#正解ラベル
correct = 10
y_train = np_utils.to_categorical(y_train, correct)



#テストデータ
#X

X_test = X_test.reshape(10000, 28, 28, 1)
X_test = X_test.astype('float32')
X_test /= X_test.max()

#y
y_test = np_utils.to_categorical(y_test, correct)

 
'''
CNNの構築
'''
 
model = Sequential()
 
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', input_shape=(28, 28, 1), activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
 
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
 
'''
学習
'''
#計測開始
startTime = time.time()
 
history = model.fit(X_train, y_train, epochs=20, batch_size=100, verbose=1, validation_data=(X_test, y_test))
 
score = model.evaluate(X_test, y_test, verbose=0)
timer = time.time() - startTime
print('Test Loss:{}'.format(score[0]))
print('Test accuracy:{}'.format(score[1]))
#処理時間
print("time:{}sec".format(timer))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 37s 610us/step - loss: 0.3170 - acc: 0.9135 - val_loss: 0.1395 - val_acc: 0.9595
# Epoch 2/20
# 60000/60000 [==============================] - 26s 434us/step - loss: 0.1153 - acc: 0.9671 - val_loss: 0.0899 - val_acc: 0.9732
# Epoch 3/20
# 60000/60000 [==============================] - 25s 411us/step - loss: 0.0821 - acc: 0.9766 - val_loss: 0.0743 - val_acc: 0.9769
# Epoch 4/20
# 60000/60000 [==============================] - 24s 396us/step - loss: 0.0676 - acc: 0.9804 - val_loss: 0.0661 - val_acc: 0.9786
# Epoch 5/20
# 60000/60000 [==============================] - 35s 577us/step - loss: 0.0576 - acc: 0.9832 - val_loss: 0.0666 - val_acc: 0.9793
# Epoch 6/20
# 60000/60000 [==============================] - 34s 572us/step - loss: 0.0512 - acc: 0.9853 - val_loss: 0.0597 - val_acc: 0.9819
# Epoch 7/20
# 60000/60000 [==============================] - 35s 579us/step - loss: 0.0472 - acc: 0.9864 - val_loss: 0.0578 - val_acc: 0.9817
# Epoch 8/20
# 60000/60000 [==============================] - 34s 564us/step - loss: 0.0424 - acc: 0.9875 - val_loss: 0.0576 - val_acc: 0.9823
# Epoch 9/20
# 60000/60000 [==============================] - 34s 575us/step - loss: 0.0386 - acc: 0.9885 - val_loss: 0.0559 - val_acc: 0.9821
# Epoch 10/20
# 60000/60000 [==============================] - 34s 571us/step - loss: 0.0352 - acc: 0.9894 - val_loss: 0.0557 - val_acc: 0.9833
# Epoch 11/20
# 60000/60000 [==============================] - 35s 577us/step - loss: 0.0323 - acc: 0.9905 - val_loss: 0.0562 - val_acc: 0.9829
# Epoch 12/20
# 60000/60000 [==============================] - 35s 581us/step - loss: 0.0290 - acc: 0.9918 - val_loss: 0.0582 - val_acc: 0.9817
# Epoch 13/20
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0271 - acc: 0.9921 - val_loss: 0.0529 - val_acc: 0.9836
# Epoch 14/20
# 60000/60000 [==============================] - 36s 594us/step - loss: 0.0245 - acc: 0.9929 - val_loss: 0.0554 - val_acc: 0.9830
# Epoch 15/20
# 60000/60000 [==============================] - 35s 579us/step - loss: 0.0235 - acc: 0.9932 - val_loss: 0.0566 - val_acc: 0.9828
# Epoch 16/20
# 60000/60000 [==============================] - 35s 581us/step - loss: 0.0206 - acc: 0.9938 - val_loss: 0.0679 - val_acc: 0.9808
# Epoch 17/20
# 60000/60000 [==============================] - 35s 575us/step - loss: 0.0196 - acc: 0.9944 - val_loss: 0.0568 - val_acc: 0.9832
# Epoch 18/20
# 60000/60000 [==============================] - 35s 577us/step - loss: 0.0173 - acc: 0.9950 - val_loss: 0.0593 - val_acc: 0.9834
# Epoch 19/20
# 60000/60000 [==============================] - 34s 571us/step - loss: 0.0155 - acc: 0.9956 - val_loss: 0.0621 - val_acc: 0.9823
# Epoch 20/20
# 60000/60000 [==============================] - 34s 574us/step - loss: 0.0142 - acc: 0.9961 - val_loss: 0.0667 - val_acc: 0.9809
# Test Loss:0.06674854468191042
# Test accuracy:0.9809
# time:666.800683259964sec
